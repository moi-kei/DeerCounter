# %%
# %pip install ultralytics==8.0.196
# %pip install clearml

import torch
import ultralytics

ultralytics.checks()

# %env CLEARML_WEB_HOST=https://app.clear.ml
# %env CLEARML_API_HOST=https://api.clear.ml
# %env CLEARML_FILES_HOST=https://files.clear.ml
# %env CLEARML_API_ACCESS_KEY=
# %env CLEARML_API_SECRET_KEY=

# %%
# %pip install -q roboflow

from roboflow import Roboflow
from clearml import Task

task = Task.init(project_name="DeerCounter", task_name="Best config")

rf = Roboflow(api_key="")
project = rf.workspace("project-yk2dj").project("all_flights")
version = project.version(1)
dataset = version.download("yolov8")

# %%
# !yolo task=detect mode=train imgsz=640 batch=32 epochs=300 data={dataset.location}/data.yaml model=yolov8n.pt cache=ram name=yolo8n_deercounter_b32_e300
